# %%
import json
from pprint import pprint

with open('car_racing.cma.1.24.log.json') as f:
    data = json.load(f)
    
pprint(data)
# Out:
# [[25,
#   -234.16547500000001,
#   [0.4047,
#    -0.2555,
#    -0.3461,
#    -0.213,
#    1.3623,
#    1.0611,
#    -0.0275,
#    0.4363,
#    0.1677,
#    0.6472,
#    -0.669,
#    0.1036,
#    -1.9288,
#    0.3813,
#    -0.3988,
#    -1.1242,
#    -0.1358,
#    -0.1206,
#    0.3893,
#    -0.4641,
#    0.6021,
#    -0.6556,
#    0.4682,
#    -0.5288,
#    1.3186,
#    0.5061,
#    0.2698,
#    -0.8967,
#    0.0281,
#    0.0927,
#    0.2137,
#    -0.1781,
#    -0.0214,
#    -1.635,
#    -1.7062,
#    0.7582,
#    -0.7231,
#    -0.2853,
#    -0.2854,
#    -0.3798,
#    1.1693,
#    -1.6786,
#    0.6026,
#    0.0561,
#    0.4748,
#    0.6676,
#    1.4753,
#    -0.3215,
#    0.9493,
#    -0.2686,
#    0.9522,
#    1.8812,
#    -0.271,
#    0.985,
#    -0.4996,
#    0.6229,
#    -0.8414,
#    -0.129,
#    0.654,
#    1.1972,
#    0.0632,
#    -1.3552,
#    0.1209,
#    0.3201,
#    0.2777,
#    -0.7552,
#    0.0297,
#    -0.1277,
#    -0.3625,
#    0.0567,
#    0.3668,
#    0.0877,
# ...

# %%
#Each entry is generation, current reward, params for (all? ) population members.
generations_and_rewards = [d[0:2] for d in data])
# Out:
# [[25, -234.16547500000001], [50, -204.37699166666667], [75, -211.22652083333332], [100, -201.68542499999998], [125, -224.6846833333333], [150, -216.38402916666666]]

# %%
#TODO Plot generations and rewards
